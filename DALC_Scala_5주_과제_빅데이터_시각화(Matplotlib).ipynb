# %% [markdown]
# <a href="https://colab.research.google.com/github/seoy9/DALC_Scala/blob/main/DALC_Scala_5%EC%A3%BC_%EA%B3%BC%EC%A0%9C_%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%8B%9C%EA%B0%81%ED%99%94(Matplotlib).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 빅데이터 시각화(Matplotlib)

# %% [markdown]
# ## 5-1 Matplotlib 소개와 사용법

# %% [markdown]
# ### 1. Matplotlib
# </br>
#
# [ __Matplotlib__ ]
# + 파이썬에서 그래프 표시를 가능하게 해주는 라이브러리
# + 다양한 운영체제에서 사용, 다양한 포맷에서 그래프 생성
#
# [ __실습 환경 설정__ ]
# + 파이썬 설치 필수
# + 코랩(Google Colab) 환경에서 기본으로 사용 가능
# </br></br>
#
# ##### 1) Matplotlib 라이브러리 사용법
# [ __Matplotlib 불러오기__ ]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# [ __기본 스타일 설정__ ]

# %%
plt.style.use('classic')

# %% [markdown]
# [ __Matplotlib__ ]

# %%
plt.savefig('my_figure.jpg')

# %% [markdown]
# [ __파일 다운로드__ ]

# %%
from goole.colab import files
files.download('my_figure.jpg')

# %% [markdown]
# ##### 2) Matplotlib 인터페이스
# [ __두 종류의 인터페이스 사용 가능__ ]
# + MATLAB 스타일
#   + 단순하고 편리함
#   + Matlab 사용자 친화적
# </br>
#
# + 객체 지향 스타일
#   + 복잡하고 상세한 설정 가능
#   + 파이썬 프로그램 친화적
# </br></br>
#
# [ __MATLAB 스타일 인터페이스__ ]
# + MathWorks 사에서 개발한 수치 해석 및 프로그래밍 환경을 제공하는 공학용 소프트웨어
# __Matplotlib은 MATLAB의 대안으로 제작__
# </br>
#
# + plt.figure() : 그림이 담길 틀 생성
# + x=np.linspace(-10,10,100) : 두 개의 패널 중 첫 번째 패널을 생성하고 현재 축(axis)을 설정
# + plt.subplot(2,1,1)
# plt.plot(s-x,np.sin(x))
# : 2행 1열 구조 그리드의 첫 번째 패널에 사인 그래프 작성
# + plt.subplot(2,1,2)
# plt.plot(x,np.cos(x));
# : 2행 1열 구조 그리드의 두 번째 패널에 코사인 그래프 작성
# </br>
#
# [ __객체 지향 스타일 인터페이스__ ]
# + 플롯 그리드를 생성
# + Ax는 두 개의 축 객체의 배열 형성 → fig, ax = plt.subplots(2,1)
# : (nrows, ncols) 2행 1열의 축 객체 생성
# + 적절한 객체의 plot() 메소드를 호출
# : ax[0].plot(x, np.sin(x))
# : ax[1].plot(x, np.cos(X));
# </br></br>
#
# __객체 지향 스타일__ : 그림이 복잡하고 많은 설정이 필요할 때
# </br>
#
# __(MATLAB스타일 & 객체지향스타일) 코드는 달라도 결과는 동일__

# %% [markdown]
# ## 5-2 선그림과 점그림

# %% [markdown]
# ### 1. Matplotlib 사용법
# </br>
#
# ##### 1) 선그림(Line plot)
# + y=f(x) 시각화
# </br></br>
#
# [ __간단한 선그림__ ]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig = plt.figure()
fig.suptitle("Example 1: Line Plot")
ax = plt.axes()

# %%
x = np.linspace(0, 10, 30)
y = np.cos(x)
fig = plt.figure()
ax = plt.axes()

# %%
plt.plot(x, y);
ax = plt.axes()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# ##### 2) 플롯 조정
# [ __선색과 스타일__ ]
# + plt.plot(x, np.sine(x-0), color='blue)
# : 색상을 이름으로 저장
# + plt.plot(x, np.sin(x-1), color='g')
# : 짧은 색상 코드(rgb, cmyk)
# + plt.plot(x, np.sin(x-2), color='0.75')
# : 회색조 지정, 0과 1사이 값
# + plt.plot(x, np.sin(x-3), color='#FFDD44')
# : 16진수 코드(RRGGBB, 00~FF 사이)
# + plt.plot(x, np.sin(x-4), color=(1.0, 0.2, 0.3))
# : RGB 튜플, 0과 1 사이 값
# + plt.plot(x, np.sin(x-5), color='chartreuse');
# : 모든 HTML 색상 이름을 지원
# </br></br>
#
# [ __축의 범위 지정__ ]

# %%
plt.plot(x, np.cos(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x, np.cos(x*2))
plt.axis([-1, 11, -1.5, 1.5]);

# %% [markdown]
# [ __축의 스케일 변경__ ]

# %%
plt.plot(x, np.exp(-x));

# %%
plt.plot(x, np.exp(-x))
plt.yscale("log"); # log, linear, symlog, logit 가능

# %% [markdown]
# [ __축의 레이블 추가__ ]

# %%
plt.plot(x, np.cos(x))
plt.title("A Cosine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)")
# Out:
# Text(0, 0.5, 'sin(x)')

# %% [markdown]
# [ __범례(Legend) 추가__ ]

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.title('Curves if Sine and Cosine')
plt.xlabel('x')
plt.legend();

# %% [markdown]
# ##### 3) 점그림(Scatter plot)
# [ __간단한 점그림__ ]

# %%
x = np.linspace(0, 10, 25)
plt.plot(x, x, 'o', color='r') # o: 원형의 점
plt.plot(x, x+2, '.', color='g') # . :o보다 작은 원형의 점
plt.plot(x, x+4, 's-', color='b') # s : 사각형(squere)
plt.plot(x, x+6, 'd--', color='c'); # d : 마름모꼴 도형(diamond)

# %%
plt.plot(x, np.sin(x), '-og');

# %% [markdown]
# ##### 4) 플롯 조정
# [ __선과 마커의 종류 색상 변경__ ]

# %%
x = np.linspace(0, 10, 30)
y = np.cos(x)
plt.plot(x, y,
         '-o', # 실선과 원형 마커
         color='gray', # 선의 색은 회색
         markersize=10, # 마커의 크기
         linewidth=3, # 선의 두께
         markerfacecolor='white', # 마커의 색
         markeredgecolor='gray', # 마커 테두리
         markeredgewidth=1.5) # 마커 테두리 두께
plt.ylim(-1.2, 1.2)
# Out:
# (-1.2, 1.2)

# %% [markdown]
# ##### 25) plt.scatter

# %%
plt.scatter(x, y, marker='o');

# %%
rng = np.random.RandomState(seed = 0)
data = rng.randn(50, 2)
x, y = data[:, 0], data[:, 1]
colors=rng.rand(50)
sizes = 1000 * rng.rand(50)
plt.subplot(2, 1, 1)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.4, cmap='plasma')
plt.colorbar() # 색상 척도 표시
plt.subplot(2, 1, 2)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.4, cmap='viridis')
plt.colorbar(); # 색상 척도 표시

# %% [markdown]
# + 다중 서브 플롯
# + (x,y)값으로 표준 정규 분로를 따르는 난수 생성
# + 컬러의 값은 0과 1사이
# + 색상 표시는 plt.colorbar() 명령어 사용

# %% [markdown]
# ## 5-3 다중서브플롯

# %% [markdown]
# ### 1. Matplotlib 사용법
# </br>
#
# ##### 1) 다중 서브 플롯 작성
# [ __서브 플롯__ ]
# + 서로 다른 그림이나 도표를 나란히 표시할 때 사용함
# + 하나의 큰 그림 내부에 있는 작은 그림을 의미함
# </br></br>
#
# [ __plt.subplot 함수__ ]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

nrows, ncols = 3, 4

for i in range(nrows * ncols):
  plt.subplot(nrows, ncols, i+1)
  plt.text(0.5, 0.5, str((nrows, ncols, i+1)), fontsize=16, ha='center')

# %%
nrows, ncols = 3, 4

fig, ax = plt.subplots(nrows, ncols, sharex='col', sharey='row')

for i in range(nrows):
  for j in range(ncols):
    ax[i,j].text(0.5, 0.5, str((i,j)), fontsize=15, ha='center', color='g');

# %% [markdown]
# [ __plt.subplots 결과__ ]
# + plt.subplot, plt.subplots : 격자형 다중 서브 플롯
# </br></br>
#
# [ __plt.GridSpec 함수__ ]

# %%
nrows, ncols = 3, 4

grid = plt.GridSpec(nrows, 4, wspace=0.4, hspace=0.4)

ax1 = plt.subplot(grid[0,0])
ax2 = plt.subplot(grid[0,1:3])
ax3 = plt.subplot(grid[1:,:2])
ax4 = plt.subplot(grid[1:,2])
ax5 = plt.subplot(grid[:,3])

# 첫 번째, 두 번째 인수 : 텍스트가 시작하는 위치 설정
# 세 번째 인수 : 텍스트의 내용
# 네 번째 인수 : 텍스트의 크기
# 다섯 번째 인수 : 가로 방향으로 가운데 정렬
# 여섯 번째 인수 : 텍스트 색상
ax1.text(0.5, 0.5, 'Fig1', fontsize=15, ha='center', color='k')
ax2.text(0.5, 0.5, 'Fig2', fontsize=15, ha='center', color='k')
ax3.text(0.5, 0.5, 'Fig3', fontsize=15, ha='center', color='k')
ax4.text(0.5, 0.5, 'Fig4', fontsize=15, ha='center', color='k')
ax5.text(0.5, 0.5, 'Fig5', fontsize=15, ha='center', color='k')
# Out:
# Text(0.5, 0.5, 'Fig5')

# %% [markdown]
# [ __plt.GridSpec 활용 사례__ ]
# + 정규 분포 데이터 만들기

# %%
mean = [0,0]
cov = [[1,1], [1,2]]
x, y = np.random.multivariate_normal(mean, cov, 5000).T

# %% [markdown]
# + GridSpec으로 축 설정하기

# %%
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1,0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1,1:], xticklabels=[], sharex=main_ax)

# %% [markdown]
# + 메인 축에 점 산포하기

# %%
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# %% [markdown]
# + 보조 축 상에 히스토그램 만들기

# %%
x_hist.hist(x, 40, histtype='stepfilled', orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled', orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
mean = [0,0]
cov = [[1,1], [1,2]]
x, y = np.random.multivariate_normal(mean, cov, 5000).T

fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1,0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1,1:], xticklabels=[], sharex=main_ax)

main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

x_hist.hist(x, 40, histtype='stepfilled', orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled', orientation='horizontal', color='gray')
y_hist.invert_xaxis()
